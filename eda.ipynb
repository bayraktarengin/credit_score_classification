# %%
import pandas as pd

# %%
df = pd.read_csv("./data/train.csv")

# %%
df.head()
# Out:
#      ID  Customer_ID  Month           Name   Age          SSN Occupation  \
# 0  5634         3392      1  Aaron Maashoh  23.0  821000265.0  Scientist
# 1  5635         3392      2  Aaron Maashoh  23.0  821000265.0  Scientist
# 2  5636         3392      3  Aaron Maashoh  23.0  821000265.0  Scientist
# 3  5637         3392      4  Aaron Maashoh  23.0  821000265.0  Scientist
# 4  5638         3392      5  Aaron Maashoh  23.0  821000265.0  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0       19114.12            1824.843333                3.0  ...        Good
# 1       19114.12            1824.843333                3.0  ...        Good
# 2       19114.12            1824.843333                3.0  ...        Good
# 3       19114.12            1824.843333                3.0  ...        Good
# 4       19114.12            1824.843333                3.0  ...        Good
#
#    Outstanding_Debt  Credit_Utilization_Ratio Credit_History_Age  \
# ...

# %%
df.describe()
# Out:
#                   ID    Customer_ID          Month            Age  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean    80631.500000   25982.666640       4.500000      33.316340
# std     43301.486619   14340.543051       2.291299      10.764812
# min      5634.000000    1006.000000       1.000000      14.000000
# 25%     43132.750000   13664.500000       2.750000      24.000000
# 50%     80631.500000   25777.000000       4.500000      33.000000
# 75%    118130.250000   38385.000000       6.250000      42.000000
# max    155629.000000   50999.000000       8.000000      56.000000
#
#                 SSN  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# count  1.000000e+05  100000.000000          100000.000000      100000.000000
# mean   5.004617e+08   50505.123449            4197.270835           5.368820
# std    2.908267e+08   38299.422093            3186.432497           2.593314
# ...

# %%
df.shape
# Out:
# (100000, 28)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        100000 non-null  int64
#  1   Customer_ID               100000 non-null  int64
#  2   Month                     100000 non-null  int64
#  3   Name                      100000 non-null  object
#  4   Age                       100000 non-null  float64
#  5   SSN                       100000 non-null  float64
#  6   Occupation                100000 non-null  object
#  7   Annual_Income             100000 non-null  float64
#  8   Monthly_Inhand_Salary     100000 non-null  float64
#  9   Num_Bank_Accounts         100000 non-null  float64
#  10  Num_Credit_Card           100000 non-null  float64
#  11  Interest_Rate             100000 non-null  float64
#  12  Num_of_Loan               100000 non-null  float64
# ...

# %%
df["Credit_Score"].value_counts()
# Out:
# Standard    53174
# Poor        28998
# Good        17828
# Name: Credit_Score, dtype: int64

# %%
numerics = ['int64', 'float64']
print(df.select_dtypes(include=numerics).columns)
print(df.select_dtypes(include="object").columns)
# Out:
# Index(['ID', 'Customer_ID', 'Month', 'Age', 'SSN', 'Annual_Income',
#        'Monthly_Inhand_Salary', 'Num_Bank_Accounts', 'Num_Credit_Card',
#        'Interest_Rate', 'Num_of_Loan', 'Delay_from_due_date',
#        'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Outstanding_Debt', 'Credit_Utilization_Ratio',
#        'Credit_History_Age', 'Total_EMI_per_month', 'Amount_invested_monthly',
#        'Monthly_Balance'],
#       dtype='object')
# Index(['Name', 'Occupation', 'Type_of_Loan', 'Credit_Mix',
#        'Payment_of_Min_Amount', 'Payment_Behaviour', 'Credit_Score'],
#       dtype='object')

# %%
num_cols_eda = ['Annual_Income',
       'Monthly_Inhand_Salary', 'Num_Bank_Accounts', 'Num_Credit_Card',
       'Interest_Rate', 'Num_of_Loan', 'Delay_from_due_date',
       'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
       'Num_Credit_Inquiries', 'Outstanding_Debt', 'Credit_Utilization_Ratio',
       'Credit_History_Age', 'Total_EMI_per_month', 'Amount_invested_monthly',
       'Monthly_Balance']
cat_cols_eda = ['Occupation', 'Type_of_Loan', 'Credit_Mix',
       'Payment_of_Min_Amount', 'Payment_Behaviour', 'Credit_Score']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Numeric features vs Credit Score

# %%
for num_col in num_cols_eda:
    plt.figure(figsize=(12,6)) 
    sns.boxplot(x="Credit_Score", y=num_col, data=df)
    plt.show()

# %% [markdown]
# According to the above visualisations we can take these features into the model
#         ['Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts', 'Num_Credit_Card',
#        'Interest_Rate', 'Num_of_Loan', 'Delay_from_due_date',
#        'Num_of_Delayed_Payment',
#        'Num_Credit_Inquiries', 'Outstanding_Debt',
#        'Credit_History_Age',
#        'Monthly_Balance']
# and filter these features out
# 'Changed_Credit_Limit', 'Credit_Utilization_Ratio', 'Total_EMI_per_month', 'Amount_invested_monthly'

# %% [markdown]
# # Categorical features vs Credit Score

# %%
#Type_of_Loan is filtered because there are more than 6200 unique variables in it and it doesnt seem to be useful.
cat_cols_eda = ['Credit_Mix', 'Payment_of_Min_Amount', 'Payment_Behaviour', 'Occupation' ] # 'Type_of_Loan' and 'Credit_Score is filtered'
for cat_col in cat_cols_eda:
    plt.figure(figsize=(12,6)) 
    plt.xticks(rotation=90)
    sns.histplot(binwidth=1,
            x=cat_col,
            hue="Credit_Score",
            data=df,
            stat="count",
            multiple="dodge")
    plt.show()

# %% [markdown]
# # We can look to the distributions of the features

# %%
df.columns
# Out:
# Index(['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation',
#        'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts',
#        'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan',
#        'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score', 'Credit_Mix_Num'],
#       dtype='object')

# %%
for num_col in num_cols_eda:
    sns.histplot(df[num_col])
    plt.show()

# %% [markdown]
# # Creating the model

# %%
df["Credit_Mix"].value_counts()
# Out:
# Standard    45848
# Good        30384
# Bad         23768
# Name: Credit_Mix, dtype: int64

# %%
# There are too much unknown variables "NM". We can consider them as missing values. 
df["Payment_of_Min_Amount"].value_counts()
# Out:
# Yes    52326
# No     35667
# NM     12007
# Name: Payment_of_Min_Amount, dtype: int64

# %%
df["Credit_Mix_Num"] = df["Credit_Mix"].map({"Standard": 1, "Good": 2, "Bad": 0})

# %%
feautures = ['Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts', 'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Credit_Mix_Num', 'Num_Credit_Inquiries', 'Outstanding_Debt', 'Credit_History_Age', 'Monthly_Balance']
target = "Credit_Score"

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
x = df[feautures]
y = df[target]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# creating a RF classifier
clf = RandomForestClassifier(n_estimators = 100)  
  
# Training the model on the training dataset
# fit function is used to train the model using the training sets as parameters
clf.fit(x_train, y_train)
  
# performing predictions on the test dataset
y_pred = clf.predict(x_test)
  
# metrics are used to find accuracy or error
from sklearn import metrics  
print()
  
# using metrics module for accuracy calculation
print("ACCURACY OF THE MODEL: ", metrics.accuracy_score(y_test, y_pred))
# Out:
# ACCURACY OF THE MODEL:  0.8079090909090909

# %%
for n_estimator in [100,400,600]:
    clf = f"clf_{n_estimator}"
    clf = RandomForestClassifier(n_estimators = n_estimator)  
  
    # Training the model on the training dataset
    # fit function is used to train the model using the training sets as parameters
    clf.fit(x_train, y_train)

    # performing predictions on the test dataset
    y_pred = clf.predict(x_test)


    # using metrics module for accuracy calculation
    print(f"ACCURACY OF THE MODEL FOR {n_estimator}: ", metrics.accuracy_score(y_test, y_pred))
# Out:
# ACCURACY OF THE MODEL FOR 100:  0.8094545454545454
# ACCURACY OF THE MODEL FOR 1000:  0.809

# %%
df["Num_Credit_Inquiries"].mean()
# Out:
# 5.79825

# %%
a = 19114.12
b = 1824.843333
c = 2
d = 2
e = 9
f = 2
g = 12
h = 3
i = 3
Num_Credit_Inquiries = 5.79825
j = 250
k = 200
l = 310

# %%
features_once = np.array([[a, b, c, d, e, f, g, h, i, Num_Credit_Inquiries, j, k, l]])

# %%
print("Predicted Credit Score = ", clf.predict(features_once))
# Out:
# Predicted Credit Score =  ['Good']

# %% [markdown]
# # Test

# %%
df_test = pd.read_csv("./data/test.csv")

# %%
df_test.columns
# Out:
# Index(['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation',
#        'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts',
#        'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan',
#        'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance'],
#       dtype='object')
